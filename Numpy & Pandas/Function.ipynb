# %%
# Function in Python
'''
def function_name(parameter): [(parameter)--> option to write]

    # Docstring - brief descprition of the function --> option to write
    # function body - statment that define what the function does
    # the body can contain one or more statment
    return value --> optional

'''
