# %%
import pandas as pd

# %%
df = pd.read_csv("Housing.csv")

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.area
# Out:
# 0      7420
# 1      8960
# 2      9960
# 3      7500
# 4      7420
#        ...
# 540    3000
# 541    2400
# 542    3620
# 543    2910
# 544    3850
# Name: area, Length: 545, dtype: int64

# %%
df[['price','area']]
# Out:
#         price  area
# 0    13300000  7420
# 1    12250000  8960
# 2    12250000  9960
# 3    12215000  7500
# 4    11410000  7420
# ..        ...   ...
# 540   1820000  3000
# 541   1767150  2400
# 542   1750000  3620
# 543   1750000  2910
# 544   1750000  3850
#
# [545 rows x 2 columns]

# %%
# row data from indexing value fetch
# loc [location]
df.loc[0]
# Out:
# price                13300000
# area                     7420
# bedrooms                    4
# bathrooms                   2
# stories                     3
# mainroad                  yes
# guestroom                  no
# basement                   no
# hotwaterheating            no
# airconditioning           yes
# parking                     2
# prefarea                  yes
# furnishingstatus    furnished
# Name: 0, dtype: object

# %%
# row data from indexing value fetch
df.loc[3]
# Out:
# price                12215000
# area                     7500
# bedrooms                    4
# bathrooms                   2
# stories                     2
# mainroad                  yes
# guestroom                  no
# basement                  yes
# hotwaterheating            no
# airconditioning           yes
# parking                     3
# prefarea                  yes
# furnishingstatus    furnished
# Name: 3, dtype: object

# %%
df.iloc[0]
# Out:
# price                13300000
# area                     7420
# bedrooms                    4
# bathrooms                   2
# stories                     3
# mainroad                  yes
# guestroom                  no
# basement                   no
# hotwaterheating            no
# airconditioning           yes
# parking                     2
# prefarea                  yes
# furnishingstatus    furnished
# Name: 0, dtype: object

# %%
# multiple rows
df.loc[[0,3,7]]
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 3  12215000   7500         4          2        2      yes        no      yes
# 7  10150000  16200         5          3        2      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 3              no             yes        3      yes        furnished
# 7              no              no        0       no      unfurnished

# %%
df.iloc[[2,8,13]]
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 2   12250000  9960         3          2        2      yes        no      yes
# 8    9870000  8100         4          1        2      yes       yes      yes
# 13   9240000  3500         4          2        2      yes        no       no
#
#    hotwaterheating airconditioning  parking prefarea furnishingstatus
# 2               no              no        2      yes   semi-furnished
# 8               no             yes        2      yes        furnished
# 13             yes              no        2       no        furnished

# %%
# filtering row
df[df['price']> 10150000]
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
# 5  10850000  7500         3          3        1      yes        no      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
# ...

# %%
# adding new columns
#df['phone_no']=[10,20,40,57,20]
df['phone_no']=10
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
# deletind a column

df = df.drop(columns=['phone_no'])
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
# insert

df.insert(3,'phone_no',[10]*545)
print(df)
# Out:
#         price  area  bedrooms  phone_no  bathrooms  stories mainroad  \
# 0    13300000  7420         4        10          2        3      yes
# 1    12250000  8960         4        10          4        4      yes
# 2    12250000  9960         3        10          2        2      yes
# 3    12215000  7500         4        10          2        2      yes
# 4    11410000  7420         4        10          1        2      yes
# ..        ...   ...       ...       ...        ...      ...      ...
# 540   1820000  3000         2        10          1        1      yes
# 541   1767150  2400         3        10          1        1       no
# 542   1750000  3620         2        10          1        1      yes
# 543   1750000  2910         3        10          1        1       no
# 544   1750000  3850         3        10          1        2      yes
#
#     guestroom basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
# rename
#                       old       new
df = df.rename(columns={'area':'location'})
df
# Out:
#         price  location  bedrooms  phone_no  bathrooms  stories mainroad  \
# 0    13300000      7420         4        10          2        3      yes
# 1    12250000      8960         4        10          4        4      yes
# 2    12250000      9960         3        10          2        2      yes
# 3    12215000      7500         4        10          2        2      yes
# 4    11410000      7420         4        10          1        2      yes
# ..        ...       ...       ...       ...        ...      ...      ...
# 540   1820000      3000         2        10          1        1      yes
# 541   1767150      2400         3        10          1        1       no
# 542   1750000      3620         2        10          1        1      yes
# 543   1750000      2910         3        10          1        1       no
# 544   1750000      3850         3        10          1        2      yes
#
#     guestroom basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
# delete another method

del df['phone_no']
df
# Out:
#         price  location  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000      7420         4          2        3      yes        no
# 1    12250000      8960         4          4        4      yes        no
# 2    12250000      9960         3          2        2      yes        no
# 3    12215000      7500         4          2        2      yes        no
# 4    11410000      7420         4          1        2      yes       yes
# ..        ...       ...       ...        ...      ...      ...       ...
# 540   1820000      3000         2          1        1      yes        no
# 541   1767150      2400         3          1        1       no        no
# 542   1750000      3620         2          1        1      yes        no
# 543   1750000      2910         3          1        1       no        no
# 544   1750000      3850         3          1        2      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
# deleting a row from df

df = df.drop(3)
df
# Out:
#         price  location  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000      7420         4          2        3      yes        no
# 1    12250000      8960         4          4        4      yes        no
# 2    12250000      9960         3          2        2      yes        no
# 4    11410000      7420         4          1        2      yes       yes
# 5    10850000      7500         3          3        1      yes        no
# ..        ...       ...       ...        ...      ...      ...       ...
# 540   1820000      3000         2          1        1      yes        no
# 541   1767150      2400         3          1        1       no        no
# 542   1750000      3620         2          1        1      yes        no
# 543   1750000      2910         3          1        1       no        no
# 544   1750000      3850         3          1        2      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
# update a value in df

df.loc[1,"location"]=2000
df
# Out:
#         price  location  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000      7420         4          2        3      yes        no
# 1    12250000      2000         4          4        4      yes        no
# 2    12250000      9960         3          2        2      yes        no
# 4    11410000      7420         4          1        2      yes       yes
# 5    10850000      7500         3          3        1      yes        no
# ..        ...       ...       ...        ...      ...      ...       ...
# 540   1820000      3000         2          1        1      yes        no
# 541   1767150      2400         3          1        1       no        no
# 542   1750000      3620         2          1        1      yes        no
# 543   1750000      2910         3          1        1       no        no
# 544   1750000      3850         3          1        2      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...
