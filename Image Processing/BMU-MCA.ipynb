# %% [markdown]
# # Image processing allows us to transform and manipulate thousands of images at a time and extract useful insights from them. It has a wide range of applications in almost every field. Python is one of the widely used programming languages for this purpose.

# %%
pip install scikit-image
# Out:
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.9 MB 218.8 kB/s eta 0:00:57
#    - -------------------------------------- 0.5/12.9 MB 218.8 kB/s eta 0:00:57
# ...

# %%
# 10 Python Image Processing Libraries

Scikit-Image
NumPy
SciPy
PIL / Pillow
OpenCV-Python
SimpleCV
Mahotas
SimpleITK
PgMagick
PyCairo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # 10 Python Image Processing Libraries
# ----> 3 Scikit-Image
#       4 NumPy
#       5 SciPy
#
# NameError: name 'Scikit' is not defined

# %%
# Pillow is a fork of PIL, so we’re importing from PIL
from PIL import Image
import warnings
warnings.filterwarnings('ignore')

# Load an image from a file
puffin_image = Image.open('F:\\scream-4-1.jpg')
#puffin_image = Image.open('FidjiSimo.jpg')

# To display a Pillow image object in Jupyter Notebook, just run a cell whose result is that image. 

puffin_image
#puffin_image.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x760>

# %%
# The file format of the source file.
print(f"Image's file format: {puffin_image.format}")

# The pixel format used by the image. Typical values are "1", "L", "RGB" or "CMYK."
print(f"Image’s pixel format: {puffin_image.mode}")

# Image size, in pixels. The size is given as a 2-tuple (width, height).
print(f"Image size (width, height): {puffin_image.size}")

# Colour palette table, if any.
print(f"Image palette: {puffin_image.palette}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # The file format of the source file.
# ----> 2 print(f"Image's file format: {puffin_image.format}")
#       4 # The pixel format used by the image. Typical values are "1", "L", "RGB" or "CMYK."
#       5 print(f"Image’s pixel format: {puffin_image.mode}")
#
# NameError: name 'puffin_image' is not defined

# %%
# importing Image module from PIL package 
from PIL import Image 

# opening a image 
im = Image.open(r"F:\lion.png") 
#im = Image.open(r"F:\smokeman.png") 
#im = Image.open(r"F:\nVehicle_logo.com.png") 
im.show()

# use getpallete 
im2 = im.getpalette() 
print(im2)
# Out:
# [0, 0, 0, 255, 255, 255, 235, 235, 235, 244, 244, 244, 252, 252, 252, 247, 247, 247, 204, 204, 204, 208, 208, 208, 193, 193, 193, 221, 221, 221, 169, 169, 169, 232, 232, 232, 215, 215, 215, 195, 195, 195, 111, 111, 111, 143, 143, 143, 79, 79, 79, 162, 162, 162, 225, 225, 225, 85, 85, 85, 184, 184, 184, 62, 62, 62, 130, 130, 130, 165, 165, 165, 149, 149, 149, 73, 73, 73, 155, 155, 155, 67, 67, 67, 178, 178, 178, 90, 90, 90, 101, 101, 101, 39, 39, 39, 135, 135, 135, 48, 48, 48, 123, 123, 123, 41, 41, 41, 50, 50, 50, 26, 26, 26, 117, 117, 117, 21, 21, 21, 104, 104, 104, 12, 12, 12, 24, 24, 24]

# %%
# Image.resize() makes a resized copy of the original image.
puffin_image_resized = puffin_image.resize((100, 100))

puffin_image_resized
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
# Unlike Image.resize(), which makes a copy of the original image,
# Image.thumbnail() modifies the original image.
# The dimensions you provide specify maximum x- and y-size
# and the method preserves the image’s aspect ratio.
# Let’s make a copy of the original and convert it
# into a thumbnail.
puffin_image_thumbnail = puffin_image.copy()
puffin_image_thumbnail.thumbnail((300, 300))
print(f"The thumbnail image’s size is: {puffin_image_thumbnail.size}.")
puffin_image_thumbnail
# Out:
# The thumbnail image’s size is: (300, 178).
# <PIL.Image.Image image mode=RGB size=300x178>

# %% [markdown]
# Flipping Images
# Pillow’s Image class provides the transpose() method for quick image flipping. transpose() takes the following arguments:
#
# Image.FLIP_LEFT_RIGHT
# Image.FLIP_TOP_BOTTOM
# Image.ROTATE_90
# Image.ROTATE_180
# Image.ROTATE_270
# Image.TRANSPOSE
# Image.TRANSVERSE
# Here’s how you would create a horizontal mirror image of the original:

# %%
image_lr_flip = puffin_image.transpose(Image.FLIP_LEFT_RIGHT)
image_lr_flip
# Out:
# <PIL.Image.Image image mode=RGB size=1280x760>

# %%
image_tb_flip = puffin_image.transpose(Image.FLIP_TOP_BOTTOM)
image_tb_flip
# Out:
# <PIL.Image.Image image mode=RGB size=1280x760>

# %% [markdown]
# The Image.ROTATE_90, Image.ROTATE_180, Image.ROTATE_270 arguments rotate the image counterclockwise 90, 180, and 270 degrees, respectively. The following rotates the image 180 degrees:

# %%
puffin_image_resized = puffin_image.resize((300, 300))
image_rot_270 = puffin_image_resized.transpose(Image.ROTATE_270)
image_rot_270
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
puffin_image_rot_18 = puffin_image.rotate(18)
puffin_image_rot_18
# Out:
# <PIL.Image.Image image mode=RGB size=1280x760>

# %% [markdown]
# Image Normalization :
# Image Normalization scales pixel values to a specific range to enhance image processing tasks. Here:
#
# -> cv2.normalize(): Normalizes pixel values.
# -> cv2.NORM_MINMAX: Scales values between 0 and 1.
# -> cv2.merge(): Combines separately normalized RGB channels.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('FidjiSimo.jpg')
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
b, g, r = cv2.split(image_rgb)

b_normalized = cv2.normalize(b.astype('float'), None, 0, 1, cv2.NORM_MINMAX)
g_normalized = cv2.normalize(g.astype('float'), None, 0, 1, cv2.NORM_MINMAX)
r_normalized = cv2.normalize(r.astype('float'), None, 0, 1, cv2.NORM_MINMAX)

normalized_image = cv2.merge((b_normalized, g_normalized, r_normalized))
print(normalized_image[:, :, 0])

plt.imshow(normalized_image)
plt.xticks([]), 
plt.yticks([]), 
plt.title('Normalized Image')
plt.show()

# %% [markdown]
# Edge detection of Image :
# Edge detection is used to find sharp edges withing image to find different objects and boundaries within a image. Canny Edge Detection is a popular edge detection method. Here:
#
# -> cv2.GaussianBlur(): Removes noise through Gaussian smoothing.
# -> cv2.Sobel(): Computes the gradient of the image.
# -> cv2.Canny(): Applies non-maximum suppression and hysteresis thresholding to detect edges.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

#img = cv2.imread('heart_shape.png')
img = cv2.imread('FidjiSimo.jpg')
image_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
edges = cv2.Canny(image_rgb, 10, 100)

fig, axs = plt.subplots(1, 2, figsize=(7, 4))
axs[0].imshow(image_rgb), axs[1].set_title('Original Image')
axs[1].imshow(edges), axs[0].set_title('Image Edges')

for ax in axs:
    ax.set_xticks([]), ax.set_yticks([])

plt.tight_layout()
plt.show()

# %% [markdown]
# Morphological Image Processing
# Morphological Image Processing involves techniques that process the structure or shape of objects in an image. It focuses on operations like dilation, erosion, opening and closing which modify the image's geometric features. These operations work by examining the image’s pixels in relation to their neighbors usually with a small mask or kernel.Here:
#
# -> cv2.dilate(): Expands object boundaries.
# -> cv2.erode(): Shrinks object boundaries.
# -> cv2.morphologyEx() with cv2.MORPH_OPEN: Removes small noise.
# -> cv2.morphologyEx() with cv2.MORPH_CLOSE: Fills small holes.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('FidjiSimo.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
kernel = np.ones((3, 3), np.uint8)

dilated = cv2.dilate(image_gray, kernel, iterations=2)
eroded = cv2.erode(image_gray, kernel, iterations=2)
opening = cv2.morphologyEx(image_gray, cv2.MORPH_OPEN, kernel)
closing = cv2.morphologyEx(image_gray, cv2.MORPH_CLOSE, kernel)

fig, axs = plt.subplots(2, 2, figsize=(7, 7))
axs[0, 0].imshow(dilated, cmap='Greys'), axs[0, 0].set_title('Dilated Image')
axs[0, 1].imshow(eroded, cmap='Greys'), axs[0, 1].set_title('Eroded Image')
axs[1, 0].imshow(opening, cmap='Greys'), axs[1, 0].set_title('Opening')
axs[1, 1].imshow(closing, cmap='Greys'), axs[1, 1].set_title('Closing')

for ax in axs.flatten():
    ax.set_xticks([]), ax.set_yticks([])

plt.tight_layout()
plt.show()

# %%
# Setting Image.rotate()’s optional “expand” parameter to True
# avoids clipping by scaling the resulting image to accomodate the rotation.
puffin_image_rot_18_expand = puffin_image.rotate(18, expand=True)
print(f"Original image dimensions: {puffin_image.size}")
print(f"Rotated expanded image dimensions: {puffin_image_rot_18_expand.size}")
puffin_image_rot_18_expand

# %%
# Image.crop() returns a new image made from the rectangular area of the original 
# specified by the 4-tuple (x_left, y_top, x_right, y_bottom).

box = (200, 300, 700, 600)
puffin_image_cropped = puffin_image.crop(box)
print(f"The cropped image’s size is: {puffin_image_cropped.size}.")
puffin_image_cropped

# %%
# converting images to the L (luminance) format, which is a grayscale image format.
# Convert image to grayscale
grayscale_image = puffin_image.convert("L")
print(f"Original image mode: {puffin_image.mode}") # Output: RGB
print(f"Grayscale image mode: {grayscale_image.mode}") # Output: L
grayscale_image

# %%
# !pip install pyqrcode
# !pip install pypng
# !pip install Pillow

import pyqrcode
import png
from PIL import Image
#inserting website name
s = input("Enter your website: ") 
print(s)
url = pyqrcode.create(s)

#saving image
img = "qr-code.png"
url.png(img, scale=10)

#opening image
im=Image.open(img)
im.show

im

# %%
with Image.open("F:\scream-4-1.jpg") as img:
    # Get the width and height of the image  
    width, height = img.size
    
    # Get the image watermark that already prepared
    logo = Image.open("logo.jpg")
            
    # Resizing the watermark into desired size
    size = (150, 150)
    logo.thumbnail(size)
    
  
    # Set the watermark position, if written as below, it will set into bottom right of image
    x = width - 100 
    y = height - 100
    
    # Integrate the image watermark into the watermark position 
    img.paste(logo, (x, y))
    
    # Show the image
    #img.show()
    print(logo)
    print(img)
    img.show()

# %%
# Python program to generate WordCloud

# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# Reads 'Youtube04-Eminem.csv' file
df = pd.read_csv(r"F:\Youtube04-Eminem.csv", encoding="latin-1")
print(df)

comment_words = ''
stopwords = set (STOPWORDS)

# iterate through the csv file
for val in df.CONTENT:

    # typecaste each val to string
    val = str (val)

    # split the value
    tokens = val.split ()

    # Converts each token into lowercase
    for i in range (len (tokens)):
        tokens[i] = tokens[i].lower ()

    comment_words += " ".join (tokens) + " "

wordcloud = WordCloud (width=800, height=800,
                       background_color='black',
                       stopwords=stopwords,
                       min_font_size=10).generate (comment_words)

# plot the WordCloud image
plt.figure (figsize=(8, 8), facecolor=None)
plt.imshow (wordcloud)
plt.axis ("on")
plt.tight_layout (pad=0)

plt.show ()

# %%
import matplotlib.pyplot as plt 
from wordcloud import WordCloud, STOPWORDS 
import numpy as np
from PIL import Image

text = open(r'F:\Youtube04-Eminem.csv',mode = 'r', encoding = 'utf-8').read() 

# The Image shape in which you wanna convert it to.
mask = np.array(Image.open(r'F:\twitter.png'))

wc = WordCloud(stopwords = STOPWORDS,
			mask = mask, 
			background_color = "black",
			max_words = 4000,
			max_font_size = 50,
			random_state = 42, 
			width = mask.shape[2],
			height = mask.shape[1])

# Finally generate the wordcloud of the given text
wc.generate(text) 
plt.imshow(wc, interpolation = "None")

plt.axis('on')
plt.show()

# %%
# !pip install opencv-python

# %%
import cv2
import warnings
warnings.filterwarnings('ignore')

image = cv2.imread("F:\wallpapernew3.jpg")     #here you can place any image of your choice in jpg,png or jpeg format.
cv2.imshow("Model", image)
cv2.waitKey(0)
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("New Model", gray_image)
cv2.waitKey(0)

inverted_image = 255 - gray_image
cv2.imshow("Inverted Model", inverted_image)
cv2.waitKey()

blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2.imshow("Sketch Model", pencil_sketch)
cv2.waitKey(0)

# %%
# https://www.analyticsvidhya.com/blog/2021/05/image-processing-using-numpy-with-practical-implementation-and-code/
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt 

img = np.array(Image.open('FidjiSimo.jpg'))
img_R, img_G, img_B, img_M, img_N = img.copy(), img.copy(), img.copy(), img.copy(), img.copy()
img_R[:, :, (1, 2)] = 0
img_G[:, :, (0, 2)] = 0
img_B[:, :, (0, 0)] = 0
img_M[:, :, (1, 1)] = 0
img_N[:, :, (2, 2)] = 1

img_rgb = np.concatenate((img_R,img_G,img_B,img_M,img_N), axis=1)
plt.figure(figsize=(15, 15))
plt.imshow(img_rgb)

# %%
# !pip install mahotas

# %%
import mahotas as mh

# Load the image
image = mh.imread('FidjiSimo.jpg')

# Print the type and dimensions of the image
print(type(image))
print(image.shape)

# %%
import mahotas as mh

# Load the image as grayscale
image = mh.imread('FidjiSimo.jpg', as_grey=True)

# Print the type and dimensions of the image
print(type(image))
print(image.shape)

# %%
import mahotas as mh
import urllib.request
from io import BytesIO

# URL of the image
url = 'https://th.bing.com/th?id=OPAC.0MYexkdBFhTsvw474C474&o=5&pid=21.1&bw=8&bc=FFFFFF&c=17&h=208&w=252&rs=1'

# Open URL and load image
with urllib.request.urlopen(url) as url:
   s = url.read()

# Convert to BytesIO object and read image
image = mh.imread(BytesIO(s))

# Print the type and dimensions of the image
print(type(image))
print(image.shape)

# %%
# Check the ouput in other windows
import cv2

pic = cv2.imread("FidjiSimo.jpg")
gray_pic = cv2.cvtColor(pic, cv2.COLOR_BGR2GRAY)

edges_pic = cv2.Canny(pic, 100,200) #getting the image with edges detected

cv2.imshow("Edge detection",edges_pic)
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %% [markdown]
# Color Detection with opencv-python

# %%
#%matplotlib inline
import cv2
import numpy as np
import matplotlib.pylab as plt

bck = cv2.imread("images/fish_bg.png")
img = cv2.imread("images/fish.png")
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

mask = cv2.inRange(hsv, (5, 75, 25), (25, 255, 255))

## slice the orange fish
imask = mask>0
orange = np.zeros_like(img, np.uint8)
orange[imask] = img[imask]

yellow = img.copy()
hsv[...,0] = hsv[...,0] + 20
yellow[imask] = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)[imask]
yellow = np.clip(yellow, 0, 255)

bckfish = cv2.bitwise_and(bck,bck, mask=imask.astype(np.uint8))
nofish = img.copy()
nofish = cv2.bitwise_and(nofish,nofish, mask=(np.bitwise_not(imask)).astype(np.uint8))
nofish = nofish + bckfish

plt.figure(figsize=(20,12))
plt.subplots_adjust(0,0,1,0.9,0.01,0.075)
plt.subplot(221), plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)), plt.axis('off'), plt.title('original', size=20)
plt.subplot(222), plt.imshow(cv2.cvtColor(orange, cv2.COLOR_BGR2RGB)), plt.axis('off'), plt.title('only fish', size=20)
plt.subplot(223), plt.imshow(cv2.cvtColor(yellow, cv2.COLOR_BGR2RGB)), plt.axis('off'), plt.title('fish color changed', size=20)
plt.subplot(224), plt.imshow(cv2.cvtColor(nofish, cv2.COLOR_BGR2RGB)), plt.axis('off'), plt.title('transparent fish', size=20)
plt.suptitle('Color Detection with opencv-python', size=25)
plt.show()

# %% [markdown]
# Gradient Blending

# %%
import cv2
print(cv2.__version__) 
import numpy as np
# read source and destination images
src = cv2.imread("images/liberty.png")
dst = cv2.imread("images/victoria.png")
# read the mask image
src_mask = cv2.imread("images/cmask.png")
print(src.shape, dst.shape, src_mask.shape)
# (480, 360, 3) (576, 768, 3) (480, 360, 3)
# this is where the CENTER of the airplane will be placed
center = (275,250) 
# clone seamlessly.
output = cv2.seamlessClone(src, dst, src_mask, center, cv2.MIXED_CLONE)
# save result
cv2.imwrite("images/liberty_victoria.png", output)
